# %%
import geopandas
cadaster = geopandas.read_file("../Data/GEOJSON/Full_Cadaster.geojson")

# %%
cadaster["CONCEDED_B"].replace(to_replace="Name unknown", value="Seminaire de St Sulpice", inplace = True)

# %%
cadaster
# Out:
#       NUM_ENREGI  VOLUME  Area_new_1  year  DATE_MM_DD  \
# 0           8885       0        1547  1876  1876-10-04
# 1          38528       0        6420  1921  1921-04-18
# 2          16431       0        1570  1889  1889-03-22
# 3           8113       0        1650  1874  1874-12-21
# 4              0       0        1529  1877  1877-12-03
# ...          ...     ...         ...   ...         ...
# 1824           0       8        2745  1826  1826-10-18
# 1825           0       8        2356  1826  1826-08-10
# 1826           0       8        2843  1826  1826-08-08
# 1827           0       8        5909  1826  1826-08-10
# 1828        6742       0        1171  1872  1872-03-30
#
#                                  SOLD_BY           SOLD_TO  \
# 0                Seminaire de St Sulpice  Magloire Lalonde
# 1                Seminaire de St Sulpice    Osias Husereau
# 2                          Basile Groulx     Joseph Groulx
# 3                Seminaire de St Sulpice   Etienne Rastoul
# ...

# %%
cadaster.to_file('../Data/GEOJSON/Full_Cadaster.geojson', driver = 'GeoJSON')
